# %% [markdown]
# <a href="https://colab.research.google.com/github/krakowiakpawel9/convnet-course/blob/master/basics/08_nn_impl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * @author: krakowiakpawel9@gmail.com
# * @site: e-smartdata.org

# %% [markdown]
# ### Implementacja prostej sieci neuronowej

# %%
import numpy as np


np.random.seed(0)

# wygenerowanie danych
X = np.array([[1.4, 0.7]])
y_true = np.array([1.80])

def initialize_parameters(n_x, n_h, n_y):
    W1 = np.random.rand(n_h, n_x)
    W2 = np.random.rand(n_h, n_y)

    return W1, W2

def forward_propagation(X, W1, W2):
    H1 = np.dot(X, W1)
    y_pred = np.dot(H1, W2)
    return H1, y_pred

def calculate_error(y_pred, y_true):
    return y_pred - y_true

def predict(X, W1, W2):
    _, y_pred = forward_propagation(X, W1, W2)
    return y_pred[0][0]

def backpropagation(X, W1, W2, learning_rate, iters=1000, precision=0.0000001):
    
    H1, y_pred = forward_propagation(X, W1, W2)
    
    for i in range(iters):
        error = calculate_error(y_pred, y_true)
        W2 = W2 - learning_rate * error * H1.T
        W1 = W1 - learning_rate * error * np.dot(X.T, W2.T)
        
        y_pred = predict(X, W1, W2)
        print('Iter #{}, y_pred: {}, error: {}'.format(i, y_pred, calculate_error(y_pred, y_true)[0]))
        
        if abs(error) < precision:
            break
        
    return W1, W2
    
def build_model():
    
    # inicjalizacja wag
    W1, W2 = initialize_parameters(2, 2, 1)

    # propagacja wprzód
    # y_pred = predict(X, W1, W2)

    # propagacja wsteczna
    W1, W2 = backpropagation(X, W1, W2, 0.01)
    
    model = {'W1': W1, 'W2': W2}
    
    return model
 
model = build_model()
# Out:
# Iter #0, y_pred: 1.4167329175956218, error: -0.38326708240437823
# Iter #1, y_pred: 1.4353544109256564, error: -0.36464558907434363
# Iter #2, y_pred: 1.4532130384317976, error: -0.34678696156820243
# Iter #3, y_pred: 1.470326450853404, error: -0.3296735491465961
# Iter #4, y_pred: 1.4867132396120653, error: -0.3132867603879348
# Iter #5, y_pred: 1.502392779191097, error: -0.2976072208089031
# Iter #6, y_pred: 1.5173850775875484, error: -0.2826149224124517
# Iter #7, y_pred: 1.5317106356174297, error: -0.26828936438257034
# Iter #8, y_pred: 1.545390315615632, error: -0.25460968438436815
# Iter #9, y_pred: 1.5584452198609022, error: -0.2415547801390978
# Iter #10, y_pred: 1.5708965788727922, error: -0.22910342112720783
# Iter #11, y_pred: 1.5827656495706255, error: -0.21723435042937456
# Iter #12, y_pred: 1.5940736231528065, error: -0.2059263768471935
# Iter #13, y_pred: 1.6048415424463867, error: -0.19515845755361338
# Iter #14, y_pred: 1.6150902283897648, error: -0.18490977161023525
# Iter #15, y_pred: 1.6248402152436427, error: -0.1751597847563573
# Iter #16, y_pred: 1.6341116940747447, error: -0.16588830592525539
# Iter #17, y_pred: 1.6429244640212646, error: -0.15707553597873547
# Iter #18, y_pred: 1.6512978908265221, error: -0.14870210917347793
# Iter #19, y_pred: 1.65925087211595, error: -0.14074912788405003
# Iter #20, y_pred: 1.6668018088905598, error: -0.1331981911094402
# Iter #21, y_pred: 1.6739685827157897, error: -0.1260314172842103
# Iter #22, y_pred: 1.6807685380966801, error: -0.1192314619033199
# Iter #23, y_pred: 1.6872184695473151, error: -0.11278153045268491
# Iter #24, y_pred: 1.693334612883283, error: -0.10666538711671714
# Iter #25, y_pred: 1.699132640289498, error: -0.10086735971050209
# Iter #26, y_pred: 1.7046276587412954, error: -0.09537234125870464
# Iter #27, y_pred: 1.7098342113834255, error: -0.09016578861657454
# Iter #28, y_pred: 1.7147662814989248, error: -0.0852337185010752
# Iter #29, y_pred: 1.7194372987272355, error: -0.08056270127276455
# Iter #30, y_pred: 1.7238601472180193, error: -0.07613985278198077
# Iter #31, y_pred: 1.7280471754335243, error: -0.07195282456647578
# Iter #32, y_pred: 1.7320102073378474, error: -0.06798979266215266
# Iter #33, y_pred: 1.7357605547358372, error: -0.06423944526416281
# Iter #34, y_pred: 1.739309030547508, error: -0.06069096945249197
# Iter #35, y_pred: 1.742665962825653, error: -0.05733403717434715
# Iter #36, y_pred: 1.7458412093447815, error: -0.05415879065521856
# Iter #37, y_pred: 1.7488441726084965, error: -0.051155827391503594
# Iter #38, y_pred: 1.751683815140073, error: -0.04831618485992695
# Iter #39, y_pred: 1.7543686749371967, error: -0.04563132506280332
# Iter #40, y_pred: 1.7569068809867605, error: -0.043093119013239534
# Iter #41, y_pred: 1.759306168749179, error: -0.040693831250821155
# Iter #42, y_pred: 1.7615738955340972, error: -0.03842610446590289
# Iter #43, y_pred: 1.7637170557005615, error: -0.03628294429943857
# Iter #44, y_pred: 1.7657422956248567, error: -0.034257704375143305
# Iter #45, y_pred: 1.7676559283883173, error: -0.032344071611682734
# Iter #46, y_pred: 1.76946394814557, error: -0.03053605185442998
# Iter #47, y_pred: 1.7711720441409393, error: -0.028827955859060728
# Iter #48, y_pred: 1.7727856143472243, error: -0.027214385652775785
# Iter #49, y_pred: 1.774309778706767, error: -0.025690221293233062
# Iter #50, y_pred: 1.7757493919597824, error: -0.024250608040217614
# Iter #51, y_pred: 1.7771090560493554, error: -0.022890943950644616
# Iter #52, y_pred: 1.7783931320963615, error: -0.021606867903638527
# Iter #53, y_pred: 1.7796057519409425, error: -0.02039424805905754
# Iter #54, y_pred: 1.7807508292500636, error: -0.019249170749936484
# Iter #55, y_pred: 1.7818320701931678, error: -0.01816792980683224
# Iter #56, y_pred: 1.782852983690069, error: -0.017147016309930985
# Iter #57, y_pred: 1.7838168912370225, error: -0.01618310876297757
# Iter #58, y_pred: 1.7847269363184028, error: -0.015273063681597199
# Iter #59, y_pred: 1.7855860934126637, error: -0.014413906587336323
# Iter #60, y_pred: 1.7863971766022715, error: -0.013602823397728558
# Iter #61, y_pred: 1.787162847798097, error: -0.012837152201903068
# Iter #62, y_pred: 1.7878856245893888, error: -0.012114375410611222
# Iter #63, y_pred: 1.7885678877309226, error: -0.011432112269077477
# Iter #64, y_pred: 1.7892118882792487, error: -0.010788111720751337
# Iter #65, y_pred: 1.7898197543901904, error: -0.01018024560980968
# Iter #66, y_pred: 1.7903934977898524, error: -0.009606502210147694
# Iter #67, y_pred: 1.7909350199314251, error: -0.009064980068574924
# Iter #68, y_pred: 1.7914461178500294, error: -0.00855388214997066
# Iter #69, y_pred: 1.791928489727734, error: -0.008071510272265936
# Iter #70, y_pred: 1.792383740180708, error: -0.007616259819292148
# Iter #71, y_pred: 1.7928133852802697, error: -0.0071866147197303665
# Iter #72, y_pred: 1.7932188573193404, error: -0.0067811426806596575
# Iter #73, y_pred: 1.7936015093355415, error: -0.006398490664458523
# Iter #74, y_pred: 1.7939626194018734, error: -0.00603738059812664
# Iter #75, y_pred: 1.7943033946955935, error: -0.005696605304406521
# Iter #76, y_pred: 1.794624975355588, error: -0.005375024644411974
# Iter #77, y_pred: 1.7949284381381774, error: -0.005071561861822671
# Iter #78, y_pred: 1.7952147998809695, error: -0.004785200119030497
# Iter #79, y_pred: 1.7954850207840012, error: -0.00451497921599886
# Iter #80, y_pred: 1.7957400075170775, error: -0.0042599924829225255
# Iter #81, y_pred: 1.7959806161618548, error: -0.004019383838145263
# Iter #82, y_pred: 1.796207654996877, error: -0.0037923450031229766
# Iter #83, y_pred: 1.796421887133432, error: -0.0035781128665679507
# Iter #84, y_pred: 1.7966240330097518, error: -0.0033759669902482248
# Iter #85, y_pred: 1.7968147727507646, error: -0.0031852272492354228
# Iter #86, y_pred: 1.7969947484002822, error: -0.003005251599717873
# Iter #87, y_pred: 1.7971645660321853, error: -0.0028354339678147156
# Iter #88, y_pred: 1.797324797746891, error: -0.0026752022531091324
# Iter #89, y_pred: 1.7974759835590643, error: -0.0025240164409356947
# Iter #90, y_pred: 1.7976186331822848, error: -0.0023813668177152802
# Iter #91, y_pred: 1.797753227716072, error: -0.0022467722839281112
# Iter #92, y_pred: 1.7978802212404479, error: -0.00211977875955216
# Iter #93, y_pred: 1.7980000423229332, error: -0.0019999576770668437
# Iter #94, y_pred: 1.798113095442642, error: -0.0018869045573579601
# Iter #95, y_pred: 1.7982197623359162, error: -0.0017802376640838613
# Iter #96, y_pred: 1.7983204032677, error: -0.0016795967323000038
# Iter #97, y_pred: 1.798415358232655, error: -0.0015846417673450741
# Iter #98, y_pred: 1.7985049480898117, error: -0.0014950519101883941
# Iter #99, y_pred: 1.7985894756343483, error: -0.0014105243656516997
# Iter #100, y_pred: 1.7986692266099173, error: -0.0013307733900826957
# Iter #101, y_pred: 1.7987444706647484, error: -0.0012555293352516372
# Iter #102, y_pred: 1.7988154622545949, error: -0.0011845377454051675
# Iter #103, y_pred: 1.7988824414954339, error: -0.001117558504566185
# Iter #104, y_pred: 1.7989456349686643, error: -0.0010543650313357134
# Iter #105, y_pred: 1.7990052564814136, error: -0.0009947435185864162
# Iter #106, y_pred: 1.7990615077844199, error: -0.0009384922155801778
# Iter #107, y_pred: 1.7991145792498247, error: -0.0008854207501753919
# Iter #108, y_pred: 1.7991646505110876, error: -0.0008353494889123958
# Iter #109, y_pred: 1.799211891067115, error: -0.0007881089328849455
# Iter #110, y_pred: 1.7992564608525794, error: -0.0007435391474206465
# Iter #111, y_pred: 1.7992985107763064, error: -0.0007014892236936188
# Iter #112, y_pred: 1.7993381832294946, error: -0.0006618167705054745
# Iter #113, y_pred: 1.7993756125654472, error: -0.0006243874345528422
# Iter #114, y_pred: 1.7994109255523956, error: -0.0005890744476044762
# Iter #115, y_pred: 1.7994442418009133, error: -0.0005557581990867089
# Iter #116, y_pred: 1.7994756741673337, error: -0.0005243258326663724
# Iter #117, y_pred: 1.7995053291345093, error: -0.0004946708654907095
# Iter #118, y_pred: 1.799533307171182, error: -0.0004666928288179495
# Iter #119, y_pred: 1.7995597030711445, error: -0.0004402969288554992
# Iter #120, y_pred: 1.7995846062733376, error: -0.00041539372666243857
# Iter #121, y_pred: 1.79960810116394, error: -0.00039189883606005615
# Iter #122, y_pred: 1.7996302673614593, error: -0.0003697326385407873
# Iter #123, y_pred: 1.7996511799857786, error: -0.0003488200142214293
# Iter #124, y_pred: 1.799670909912054, error: -0.0003290900879460157
# Iter #125, y_pred: 1.7996895240103152, error: -0.0003104759896848108
# Iter #126, y_pred: 1.7997070853715664, error: -0.00029291462843361593
# Iter #127, y_pred: 1.7997236535211532, error: -0.00027634647884688945
# Iter #128, y_pred: 1.7997392846200977, error: -0.00026071537990235427
# Iter #129, y_pred: 1.7997540316550906, error: -0.00024596834490941966
# Iter #130, y_pred: 1.7997679446177701, error: -0.00023205538222992317
# Iter #131, y_pred: 1.7997810706738873, error: -0.00021892932611278226
# Iter #132, y_pred: 1.7997934543229364, error: -0.00020654567706368532
# Iter #133, y_pred: 1.7998051375487762, error: -0.00019486245122379842
# Iter #134, y_pred: 1.7998161599617548, error: -0.00018384003824523099
# Iter #135, y_pred: 1.7998265589328146, error: -0.0001734410671854203
# Iter #136, y_pred: 1.799836369720028, error: -0.00016363027997212676
# Iter #137, y_pred: 1.799845625587993, error: -0.00015437441200694124
# Iter #138, y_pred: 1.7998543579204873, error: -0.00014564207951273112
# Iter #139, y_pred: 1.799862596326761, error: -0.0001374036732391115
# Iter #140, y_pred: 1.7998703687418316, error: -0.00012963125816845
# Iter #141, y_pred: 1.7998777015211114, error: -0.00012229847888867162
# Iter #142, y_pred: 1.7998846195296938, error: -0.00011538047030623666
# Iter #143, y_pred: 1.799891146226593, error: -0.00010885377340708047
# Iter #144, y_pred: 1.7998973037442298, error: -0.00010269625577019603
# Iter #145, y_pred: 1.7999031129634249, error: -9.688703657517728e-05
# Iter #146, y_pred: 1.7999085935841541, error: -9.140641584592935e-05
# Iter #147, y_pred: 1.799913764192309, error: -8.623580769095973e-05
# Iter #148, y_pred: 1.799918642322683, error: -8.135767731709542e-05
# Iter #149, y_pred: 1.7999232445183992, error: -7.67554816007987e-05
# Iter #150, y_pred: 1.7999275863869815, error: -7.241361301857374e-05
# Iter #151, y_pred: 1.7999316826532534, error: -6.831734674661583e-05
# Iter #152, y_pred: 1.7999355472092504, error: -6.445279074962507e-05
# Iter #153, y_pred: 1.799939193161308, error: -6.0806838692029075e-05
# Iter #154, y_pred: 1.7999426328744939, error: -5.7367125506191385e-05
# Iter #155, y_pred: 1.799945878014522, error: -5.412198547793956e-05
# Iter #156, y_pred: 1.7999489395873012, error: -5.106041269886674e-05
# Iter #157, y_pred: 1.7999518279762479, error: -4.817202375217988e-05
# Iter #158, y_pred: 1.799954552977487, error: -4.544702251307875e-05
# Iter #159, y_pred: 1.7999571238330674, error: -4.287616693265939e-05
# Iter #160, y_pred: 1.7999595492622933, error: -4.0450737706754225e-05
# Iter #161, y_pred: 1.7999618374912902, error: -3.8162508709804754e-05
# Iter #162, y_pred: 1.799963996280895, error: -3.600371910494893e-05
# Iter #163, y_pred: 1.799966032952973, error: -3.396704702707254e-05
# Iter #164, y_pred: 1.7999679544152407, error: -3.204558475933261e-05
# Iter #165, y_pred: 1.7999697671846926, error: -3.0232815307451588e-05
# Iter #166, y_pred: 1.799971477409698, error: -2.852259030206028e-05
# Iter #167, y_pred: 1.7999730908908496, error: -2.6909109150485833e-05
# Iter #168, y_pred: 1.7999746131006338, error: -2.538689936626426e-05
# Iter #169, y_pred: 1.799976049201989, error: -2.3950798011096452e-05
# Iter #170, y_pred: 1.7999774040658125, error: -2.2595934187519262e-05
# Iter #171, y_pred: 1.7999786822874793, error: -2.1317712520785292e-05
# Iter #172, y_pred: 1.7999798882024258, error: -2.0111797574218215e-05
# Iter #173, y_pred: 1.7999810259008524, error: -1.8974099147639478e-05
# Iter #174, y_pred: 1.7999820992415938, error: -1.7900758406241835e-05
# Iter #175, y_pred: 1.7999831118652074, error: -1.6888134792614196e-05
# Iter #176, y_pred: 1.7999840672063177, error: -1.5932793682393864e-05
# Iter #177, y_pred: 1.7999849685052656, error: -1.5031494734474293e-05
# Iter #178, y_pred: 1.7999858188190978, error: -1.4181180902239632e-05
# Iter #179, y_pred: 1.7999866210319349, error: -1.3378968065191899e-05
# Iter #180, y_pred: 1.7999873778647504, error: -1.2622135249662492e-05
# Iter #181, y_pred: 1.799988091884603, error: -1.1908115397085695e-05
# Iter #182, y_pred: 1.7999887655133393, error: -1.1234486660738341e-05
# Iter #183, y_pred: 1.79998940103581, error: -1.0598964190089433e-05
# Iter #184, y_pred: 1.7999900006076173, error: -9.999392382775696e-06
# Iter #185, y_pred: 1.7999905662624278, error: -9.433737572228651e-06
# Iter #186, y_pred: 1.7999910999188675, error: -8.900081132523496e-06
# Iter #187, y_pred: 1.799991603387032, error: -8.396612968031292e-06
# Iter #188, y_pred: 1.7999920783746233, error: -7.921625376772212e-06
# Iter #189, y_pred: 1.7999925264927417, error: -7.473507258382028e-06
# Iter #190, y_pred: 1.7999929492613538, error: -7.05073864626371e-06
# Iter #191, y_pred: 1.7999933481144414, error: -6.651885558595083e-06
# Iter #192, y_pred: 1.7999937244048727, error: -6.275595127336331e-06
# Iter #193, y_pred: 1.7999940794089837, error: -5.920591016339571e-06
# Iter #194, y_pred: 1.7999944143309126, error: -5.585669087482259e-06
# Iter #195, y_pred: 1.7999947303066803, error: -5.26969331970939e-06
# Iter #196, y_pred: 1.7999950284080466, error: -4.971591953450982e-06
# Iter #197, y_pred: 1.7999953096461425, error: -4.690353857528251e-06
# Iter #198, y_pred: 1.7999955749749015, error: -4.425025098564461e-06
# Iter #199, y_pred: 1.7999958252942951, error: -4.174705704906856e-06
# Iter #200, y_pred: 1.7999960614533834, error: -3.938546616621963e-06
# Iter #201, y_pred: 1.7999962842531987, error: -3.7157468013582218e-06
# Iter #202, y_pred: 1.7999964944494589, error: -3.5055505411829557e-06
# Iter #203, y_pred: 1.799996692755132, error: -3.307244867967185e-06
# Iter #204, y_pred: 1.799996879842854, error: -3.1201571459860133e-06
# Iter #205, y_pred: 1.7999970563472127, error: -2.943652787301687e-06
# Iter #206, y_pred: 1.7999972228668961, error: -2.7771331039261327e-06
# Iter #207, y_pred: 1.7999973799667268, error: -2.620033273226241e-06
# Iter #208, y_pred: 1.7999975281795746, error: -2.4718204254536857e-06
# Iter #209, y_pred: 1.799997668008167, error: -2.3319918329711697e-06
# Iter #210, y_pred: 1.7999977999267927, error: -2.20007320739235e-06
# Iter #211, y_pred: 1.7999979243829087, error: -2.0756170913127647e-06
# Iter #212, y_pred: 1.7999980417986627, error: -1.9582013373042884e-06
# Iter #213, y_pred: 1.7999981525723197, error: -1.8474276803903678e-06
# Iter #214, y_pred: 1.7999982570796167, error: -1.742920383351887e-06
# Iter #215, y_pred: 1.7999983556750347, error: -1.6443249652997594e-06
# Iter #216, y_pred: 1.7999984486930036, error: -1.5513069964168125e-06
# Iter #217, y_pred: 1.7999985364490336, error: -1.463550966418481e-06
# Iter #218, y_pred: 1.7999986192407866, error: -1.3807592134096325e-06
# Iter #219, y_pred: 1.7999986973490878, error: -1.302650912249348e-06
# Iter #220, y_pred: 1.7999987710388754, error: -1.2289611246441012e-06
# Iter #221, y_pred: 1.7999988405600997, error: -1.1594399003111988e-06
# Iter #222, y_pred: 1.7999989061485726, error: -1.093851427436121e-06
# Iter #223, y_pred: 1.7999989680267658, error: -1.031973234200123e-06
# Iter #224, y_pred: 1.7999990264045667, error: -9.735954333844887e-07
# Iter #225, y_pred: 1.799999081479989, error: -9.185200109396163e-07
# Iter #226, y_pred: 1.799999133439845, error: -8.665601549662227e-07
# Iter #227, y_pred: 1.7999991824603794, error: -8.175396206677732e-07
# Iter #228, y_pred: 1.7999992287078665, error: -7.712921334945833e-07
# Iter #229, y_pred: 1.7999992723391756, error: -7.276608244843885e-07
# Iter #230, y_pred: 1.7999993135023007, error: -6.864976993536942e-07
# Iter #231, y_pred: 1.7999993523368651, error: -6.476631349006112e-07
# Iter #232, y_pred: 1.7999993889745933, error: -6.110254067159815e-07
# Iter #233, y_pred: 1.7999994235397585, error: -5.764602415414544e-07
# Iter #234, y_pred: 1.799999456149603, error: -5.438503969390496e-07
# Iter #235, y_pred: 1.7999994869147382, error: -5.130852618329129e-07
# Iter #236, y_pred: 1.799999515939517, error: -4.840604830302908e-07
# Iter #237, y_pred: 1.79999954332239, error: -4.566776099501624e-07
# Iter #238, y_pred: 1.7999995691562387, error: -4.308437613342875e-07
# Iter #239, y_pred: 1.7999995935286894, error: -4.064713106100015e-07
# Iter #240, y_pred: 1.7999996165224124, error: -3.8347758768431106e-07
# Iter #241, y_pred: 1.7999996382154007, error: -3.6178459938973617e-07
# Iter #242, y_pred: 1.7999996586812368, error: -3.4131876325282917e-07
# Iter #243, y_pred: 1.7999996779893381, error: -3.2201066191284156e-07
# Iter #244, y_pred: 1.7999996962051976, error: -3.0379480242537227e-07
# Iter #245, y_pred: 1.7999997133906016, error: -2.8660939843661026e-07
# Iter #246, y_pred: 1.799999729603843, error: -2.703961570205138e-07
# Iter #247, y_pred: 1.7999997448999157, error: -2.5510008438978105e-07
# Iter #248, y_pred: 1.7999997593307029, error: -2.4066929715793606e-07
# Iter #249, y_pred: 1.7999997729451533, error: -2.2705484670204612e-07
# Iter #250, y_pred: 1.7999997857894465, error: -2.1421055351744656e-07
# Iter #251, y_pred: 1.799999797907149, error: -2.0209285112038344e-07
# Iter #252, y_pred: 1.799999809339364, error: -1.906606359458607e-07
# Iter #253, y_pred: 1.7999998201248686, error: -1.7987513145634182e-07
# Iter #254, y_pred: 1.799999830300247, error: -1.6969975313863017e-07
# Iter #255, y_pred: 1.7999998399000128, error: -1.6009998726751462e-07
# Iter #256, y_pred: 1.7999998489567286, error: -1.5104327144577212e-07
# Iter #257, y_pred: 1.7999998575011134, error: -1.424988866904897e-07
# Iter #258, y_pred: 1.7999998655621505, error: -1.3443784951938653e-07
# Iter #259, y_pred: 1.7999998731671816, error: -1.2683281847003514e-07
# Iter #260, y_pred: 1.7999998803420028, error: -1.1965799728841375e-07
# Iter #261, y_pred: 1.7999998871109508, error: -1.1288904921968879e-07
# Iter #262, y_pred: 1.7999998934969854, error: -1.0650301462966638e-07
# Iter #263, y_pred: 1.7999998995217679, error: -1.0047823217895768e-07
# Iter #264, y_pred: 1.7999999052057332, error: -9.479426688052683e-08
# Iter #265, y_pred: 1.7999999105681617, error: -8.943183837928359e-08

# %%
predict(X, model['W1'], model['W2'])
# Out:
# 1.7999999105681617

# %%
X = np.array([[1.4, 0.7]])
X.shape
# Out:
# (1, 2)
